# %%
import xalpha as xa
import pandas as pd

# %% [markdown]
# # 多基金或指数的综合分析

# %%
sz50, hs300, zz500, cyb = (
    xa.indexinfo("0000016"),
    xa.indexinfo("0000300"),
    xa.indexinfo("0000905"),
    xa.indexinfo("1399006"),
)
# 四个基本指数的数据获取

# %%
comparison = xa.evaluate(sz50, hs300, zz500, cyb)
# 综合分析，未指定 start 参数的化，比较的开始时间默认为最新的指数的开始时间

# %%
comparison.totprice[comparison.totprice["date"] > "2018-08-01"]  # 这一类的核心数据，是归一化过的净值表
# Out:
#            date   0000016   0000300   0000905   1399006
# 1987 2018-08-02  1.276693  1.228411  1.241002  1.551620
# 1988 2018-08-03  1.262668  1.208123  1.224543  1.522355
# 1989 2018-08-06  1.259023  1.192813  1.198585  1.480422
# 1990 2018-08-07  1.297341  1.227650  1.231280  1.520130
# 1991 2018-08-08  1.280191  1.207840  1.212326  1.487575
# 1992 2018-08-09  1.310335  1.238094  1.243178  1.538795
# 1993 2018-08-10  1.309597  1.240823  1.249572  1.553284

# %%
comparison.v_netvalue()  # 指数起点归一化净值的变动情况，神创威武
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="616a889e44034cfbb3216aa8b7999e72" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_616a889e44034cfbb3216aa8b7999e72 = echarts.init(document.getElementById('616a889e44034cfbb3216aa8b7999e72'), 'light', {renderer: 'canvas'});
#
# var option_616a889e44034cfbb3216aa8b7999e72 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4567203,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0a\u8bc1\uff15\uff10",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2010-06-01T00:00:00",
#                     0.9999999999999999
#                 ],
#                 [
#                     "2010-06-02T00:00:00",
#                     0.9981532170644836
#                 ],
#                 [
#                     "2010-06-03T00:00:00",
#                     0.9914802096020155
#                 ],
#                 [
#                     "2010-06-04T00:00:00",
#                     0.9911155615266459
#                 ],
#                 [
#                     "2010-06-07T00:00:00",
#                     0.9696201591267698
#                 ],
#                 [
#                     "2010-06-08T00:00:00",
#                     0.9653129172264564
#                 ],
#                 [
#                     "2010-06-09T00:00:00",
#                     0.9976269100862598
#                 ],
#                 [
#                     "2010-06-10T00:00:00",
#                     0.9803246989691498
#                 ],
#                 [
#                     "2010-06-11T00:00:00",
#                     0.9852278291877503
#                 ],
#                 [
#                     "2010-06-17T00:00:00",
#                     0.9846717016352137
#                 ],
#                 [
#                     "2010-06-18T00:00:00",
#                     0.9787797839525549
#                 ],
#                 [
#                     "2010-06-21T00:00:00",
#                     1.0116059582553814
#                 ],
#                 [
#                     "2010-06-22T00:00:00",
#                     1.009715229210351
#                 ],
#                 [
#                     "2010-06-23T00:00:00",
#                     1.0011478305270602
#                 ],
#                 [
#                     "2010-06-24T00:00:00",
#                     1.0016814618568695
#                 ],
#                 [
#                     "2010-06-25T00:00:00",
#                     1.0023427461714567
#                 ],
#                 [
#                     "2010-06-28T00:00:00",
#                     0.9994961892445036
#                 ],
#                 [
#                     "2010-06-29T00:00:00",
#                     0.958986246960394
#                 ],
#                 [
#                     "2010-06-30T00:00:00",
#                     0.9516995634686454
#                 ],
#                 [
#                     "2010-07-01T00:00:00",
#                     0.9416400897337702
#                 ],
#                 [
#                     "2010-07-02T00:00:00",
#                     0.9482837997898956
#                 ],
#                 [
#                     "2010-07-05T00:00:00",
#                     0.9404781336715091
#                 ],
#                 [
#                     "2010-07-06T00:00:00",
#                     0.9555113653009889
#                 ],
#                 [
#                     "2010-07-07T00:00:00",
#                     0.9571656224233978
#                 ],
#                 [
#                     "2010-07-08T00:00:00",
#                     0.9564195848976056
#                 ],
#                 [
#                     "2010-07-09T00:00:00",
#                     0.978482624545367
#                 ],
#                 [
#                     "2010-07-12T00:00:00",
#                     0.987569005855296
#                 ],
#                 [
#                     "2010-07-13T00:00:00",
#                     0.9726487785074226
#                 ],
#                 [
#                     "2010-07-14T00:00:00",
#                     0.9799134889444144
#                 ],
#                 [
#                     "2010-07-15T00:00:00",
#                     0.9629785417425258
#                 ],
#                 [
#                     "2010-07-16T00:00:00",
#                     0.9622204713534146
#                 ],
#                 [
#                     "2010-07-19T00:00:00",
#                     0.9827856811019172
#                 ],
#                 [
#                     "2010-07-20T00:00:00",
#                     0.9992325125874213
#                 ],
#                 [
#                     "2010-07-21T00:00:00",
#                     1.0015161407782227
#                 ],
#                 [
#                     "2010-07-22T00:00:00",
#                     1.0117425050956559
#                 ],
#                 [
#                     "2010-07-23T00:00:00",
#                     1.0177976511850801
#                 ],
#                 [
#                     "2010-07-26T00:00:00",
#                     1.0211558663870857
#                 ],
#                 [
#                     "2010-07-27T00:00:00",
#                     1.0128919051266276
#                 ],
#                 [
#                     "2010-07-28T00:00:00",
#                     1.0377706347910884
#                 ],
#                 [
#                     "2010-07-29T00:00:00",
#                     1.043128921143938
#                 ],
#                 [
#                     "2010-07-30T00:00:00",
#                     1.0394091968743853
#                 ],
#                 [
#                     "2010-08-02T00:00:00",
#                     1.0545261353791293
#                 ],
#                 [
#                     "2010-08-03T00:00:00",
#                     1.0350428369934164
#                 ],
#                 [
#                     "2010-08-04T00:00:00",
#                     1.0366704125493347
#                 ],
#                 [
#                     "2010-08-05T00:00:00",
#                     1.022445998602095
#                 ],
#                 [
#                     "2010-08-06T00:00:00",
#                     1.035468695721323
#                 ],
#                 [
#                     "2010-08-09T00:00:00",
#                     1.0400668190131797
#                 ],
#                 [
#                     "2010-08-10T00:00:00",
#                     1.012113954354641
#                 ],
#                 [
#                     "2010-08-11T00:00:00",
#                     1.0148642483750403
#                 ],
#                 [
#                     "2010-08-12T00:00:00",
#                     1.0015794441026413
#                 ],
#                 [
#                     "2010-08-13T00:00:00",
#                     1.0100652285825495
#                 ],
#                 [
#                     "2010-08-16T00:00:00",
#                     1.03131840421213
#                 ],

# %%
comparison.v_correlation()  # 指数之间的相关系数，创业板比较独立
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e480d2b591b74ead85f44d762b134849" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e480d2b591b74ead85f44d762b134849 = echarts.init(document.getElementById('e480d2b591b74ead85f44d762b134849'), 'light', {renderer: 'canvas'});
#
# var option_e480d2b591b74ead85f44d762b134849 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5709929,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "data": [
#                 [
#                     0,
#                     0,
#                     1.0
#                 ],
#                 [
#                     0,
#                     1,
#                     0.9437971431489975
#                 ],
#                 [
#                     0,
#                     2,
#                     0.6561246057166692
#                 ],
#                 [
#                     0,
#                     3,
#                     0.4663393913272071
#                 ],
#                 [
#                     1,
#                     0,
#                     0.9437971431489975
#                 ],
#                 [
#                     1,
#                     1,
#                     1.0
#                 ],
#                 [
#                     1,
#                     2,
#                     0.8498728847194187
#                 ],
#                 [
#                     1,
#                     3,
#                     0.6706560045659226
#                 ],
#                 [
#                     2,
#                     0,
#                     0.6561246057166692
#                 ],
#                 [
#                     2,
#                     1,
#                     0.8498728847194187
#                 ],
#                 [
#                     2,
#                     2,
#                     1.0
#                 ],
#                 [
#                     2,
#                     3,
#                     0.8818273549331467
#                 ],
#                 [
#                     3,
#                     0,
#                     0.4663393913272071
#                 ],
#                 [
#                     3,
#                     1,
#                     0.6706560045659226
#                 ],
#                 [
#                     3,
#                     2,
#                     0.8818273549331467
#                 ],
#                 [
#                     3,
#                     3,
#                     1.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 5709929
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "0000016",
#                 "0000300",
#                 "0000905",
#                 "1399006"
#             ],
#             "splitArea": {
#                 "show": true
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "0000016",
#                 "0000300",
#                 "0000905",
#                 "1399006"
#             ],
#             "splitArea": {
#                 "show": true
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": -1,
#         "max": 1,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "horizontal",
#         "left": "center",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_e480d2b591b74ead85f44d762b134849.setOption(option_e480d2b591b74ead85f44d762b134849);
#
#     });
# </script>

# %%
comparison.correlation_table()  # 嫌图花哨可以直接看相关系数的数据
# Out:
#           0000016   0000300   0000905   1399006
# 0000016  1.000000  0.943797  0.656125  0.466339
# 0000300  0.943797  1.000000  0.849873  0.670656
# 0000905  0.656125  0.849873  1.000000  0.881827
# 1399006  0.466339  0.670656  0.881827  1.000000
