# %%
import sys

sys.path.insert(0, "../../")
from pyecharts import online

online()
#  演示必要的准备代码，使用该库时不需重复此单元格命令

# %%
import xalpha as xa
import pandas as pd

# %% [markdown]
# # 基金定投探究

# %% [markdown]
# 波动和成长，标的的性质如何影响定投的成绩

# %%
zz500 = xa.indexinfo("0000905")
zz500b = xa.indexinfo("0000831")
# 采用中证500和500低贝进行研究

# %%
zz500.bcmkset(xa.cashinfo())
zz500b.bcmkset(xa.cashinfo())

# %%
zz500.algorithm_volatility(), zz500b.algorithm_volatility()
# 低波波动性低的也没那么明显
# Out:
# (0.31811907574774867, 0.29669632893344722)

# %%
zz500.total_annualized_returns(), zz500b.total_annualized_returns()
# 不过低波的收益率可是强多了
# Out:
# (0.12470000000000001, 0.1726)

# %%
auto = xa.policy.scheduled(
    zz500, 1000, pd.date_range("2011-01-01", "2015-01-01", freq="W-THU")
)
autob = xa.policy.scheduled(
    zz500b, 1000, pd.date_range("2011-01-01", "2015-01-01", freq="W-THU")
)
# 每周四定投1000元

# %%
zz500t = xa.trade(zz500, auto.status)
zz500bt = xa.trade(zz500b, autob.status)

# %%
zz500t.xirrrate("2015-06-01"), zz500bt.xirrrate("2015-06-01")
# 到牛市顶部时，年化收益率竟然差不多
# Out:
# (0.45607187160394663, 0.46458845644291197)

# %%
zz500t.dailyreport("2015-06-01")
# Out:
#     基金名称     基金代码       当日净值    单位成本      持有份额       基金现值     基金总申购    历史最大占用  \
# 0  中证500  0000905  10.627208  3.9089  53211.76  565492.42  208000.0  208000.0
#
#      基金持有成本  基金分红与赎回       换手率     基金收益总额     投资收益率
# 0  208000.0      0.0  0.113566  357492.42  171.8714

# %%
zz500bt.dailyreport("2015-06-01")
# Out:
#       基金名称     基金代码       当日净值    单位成本      持有份额       基金现值     基金总申购  \
# 0  500µÍ±´  0000831  14.630401  5.2911  39311.42  575141.83  208000.0
#
#      历史最大占用    基金持有成本  基金分红与赎回       换手率     基金收益总额     投资收益率
# 0  208000.0  208000.0      0.0  0.113566  367141.83  176.5105

# %% [markdown]
# 由此可见，虽然低波的一次性投入对应的年化收益很高，但最终定投下来和普通500指数的收益差不多。。。。

# %%
# 还是换创业板暴力一发吧，让你们领略一下15年神创的风采
cyb = xa.indexinfo("1399006")

# %%
cyb.bcmkset(xa.cashinfo())

# %%
cyb.total_annualized_returns("2015-06-01"), cyb.algorithm_volatility("2015-06-01")
# 令人眼红的收益率
# Out:
# (0.30730000000000002, 0.30155185277351393)

# %%
autoc = xa.policy.scheduled(
    cyb, 1000, pd.date_range("2011-01-01", "2015-01-01", freq="W-THU")
)

# %%
cybt = xa.trade(cyb, autoc.status)

# %%
cybt.dailyreport("2015-06-01")
# 就问你怕不怕，同样的投入现金流，收益绝对值接近翻倍
# Out:
#    基金名称     基金代码      当日净值    单位成本       持有份额       基金现值     基金总申购    历史最大占用  \
# 0  创业板指  1399006  3.821031  0.9779  212690.33  812696.24  208000.0  208000.0
#
#      基金持有成本  基金分红与赎回       换手率     基金收益总额     投资收益率
# 0  208000.0      0.0  0.113566  604696.24  290.7193

# %%
cybt.xirrrate("2015-06-01")  # 60%多的年化
# Out:
# 0.6452718352308852

# %%
# 不过如果不幸没有止盈，持有到现在
cybt.xirrrate()
# Out:
# 0.07698746449319872

# %% [markdown]
# 让我这次定投一个大蓝筹

# %%
sz50 = xa.indexinfo("0000016")

# %%
autod = xa.policy.scheduled(
    sz50, 1000, pd.date_range("2011-01-01", "2015-01-01", freq="W-THU")
)

# %%
sz50t = xa.trade(sz50, autod.status)

# %%
sz50t.dailyreport("2015-06-01")
# Out:
#    基金名称     基金代码      当日净值    单位成本       持有份额       基金现值     基金总申购    历史最大占用  \
# 0  上证５０  0000016  3.207919  1.6901  123070.13  394798.98  208000.0  208000.0
#
#      基金持有成本  基金分红与赎回       换手率     基金收益总额    投资收益率
# 0  208000.0      0.0  0.113566  186798.98  89.8072

# %%
sz50t.xirrrate("2015-06-01")
# 不愧江湖诨号大烂臭，收益在15年的牛市中远小于中小盘
# Out:
# 0.28189135734500326

# %%
sz50.bcmkset(xa.cashinfo(), start="2011-01-01")

# %%
sz50.algorithm_volatility("2015-06-01")
# 真点低波
# Out:
# 0.2333094161336661

# %%
# 持有到现在，即使这几年大盘股反杀，依旧不如创业板
sz50t.xirrrate()
# Out:
# 0.06558331152460622

# %% [markdown]
# ### 试一下定期不定额的加强效果

# %%
autoe = xa.policy.scheduled_tune(
    zz500,
    600,
    times=pd.date_range("2011-01-01", "2015-01-01", freq="W-THU"),
    piece=[(3, 5), (3.5, 3), (4, 2), (5.5, 1)],
)

# %%
zz500t2 = xa.trade(zz500, autoe.status)

# %%
zz500t2.v_tradevolume()  # 每周的买入情况
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6448baf0e90a494da2b8f7b2ebbf812f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6448baf0e90a494da2b8f7b2ebbf812f = echarts.init(document.getElementById('6448baf0e90a494da2b8f7b2ebbf812f'), 'light', {renderer: 'canvas'});
#
# var option_6448baf0e90a494da2b8f7b2ebbf812f = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7784513,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2011-01-06T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-01-13T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-01-20T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-01-27T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-02-09T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-02-10T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-02-17T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-02-24T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-03-03T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-03-10T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-03-17T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-03-24T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-03-31T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-04-07T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-04-14T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-04-21T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-04-28T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-05-05T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-05-12T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-05-19T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-05-26T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-06-02T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-06-09T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-06-16T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-06-23T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-06-30T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-07-07T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-07-14T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-07-21T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-07-28T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-08-04T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-08-11T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-08-18T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-08-25T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-09-01T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-09-08T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-09-15T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-09-22T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-09-29T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-10-10T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-10-13T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-10-20T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-10-27T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-11-03T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-11-10T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-11-17T00:00:00",
#                     -600.0
#                 ],
#                 [
#                     "2011-11-24T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-12-01T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-12-08T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2011-12-15T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2011-12-22T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2011-12-29T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2012-01-05T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2012-01-12T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2012-01-19T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2012-01-30T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2012-02-02T00:00:00",
#                     -1800.0
#                 ],
#                 [
#                     "2012-02-09T00:00:00",
#                     -1200.0
#                 ],
#                 [
#                     "2012-02-16T00:00:00",
#                     -1200.0
#                 ],
#                 [

# %%
zz500t2.v_tradecost(end="2015-06-01")  # 定投对于成本的平滑
# 看似收益很高，但你真的能承受住开始定投后长达两年多的浮亏么，甚至很多至暗时刻，浮亏超过20%，能坚持下来么
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="05b25cfb8dd549a2a89b492c6eb991bc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_05b25cfb8dd549a2a89b492c6eb991bc = echarts.init(document.getElementById('05b25cfb8dd549a2a89b492c6eb991bc'), 'light', {renderer: 'canvas'});
#
# var option_05b25cfb8dd549a2a89b492c6eb991bc = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7087249,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "fundvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2005-01-04T00:00:00",
#                     1.0
#                 ],
#                 [
#                     "2005-01-05T00:00:00",
#                     1.016921159555389
#                 ],
#                 [
#                     "2005-01-06T00:00:00",
#                     1.0077715744784332
#                 ],
#                 [
#                     "2005-01-07T00:00:00",
#                     1.0108214361707517
#                 ],
#                 [
#                     "2005-01-10T00:00:00",
#                     1.0196670483215629
#                 ],
#                 [
#                     "2005-01-11T00:00:00",
#                     1.021693534495861
#                 ],
#                 [
#                     "2005-01-12T00:00:00",
#                     1.0219772425602627
#                 ],
#                 [
#                     "2005-01-13T00:00:00",
#                     1.026486174298076
#                 ],
#                 [
#                     "2005-01-14T00:00:00",
#                     1.0134153384738533
#                 ],
#                 [
#                     "2005-01-17T00:00:00",
#                     0.9904653825499276
#                 ],
#                 [
#                     "2005-01-18T00:00:00",
#                     1.004549461461299
#                 ],
#                 [
#                     "2005-01-19T00:00:00",
#                     0.9993008622698673
#                 ],
#                 [
#                     "2005-01-20T00:00:00",
#                     0.9853383725289535
#                 ],
#                 [
#                     "2005-01-21T00:00:00",
#                     1.001611056508567
#                 ],
#                 [
#                     "2005-01-24T00:00:00",
#                     1.0215212831710456
#                 ],
#                 [
#                     "2005-01-25T00:00:00",
#                     1.0127871277598208
#                 ],
#                 [
#                     "2005-01-26T00:00:00",
#                     1.0010436403797636
#                 ],
#                 [
#                     "2005-01-27T00:00:00",
#                     0.984233937563961
#                 ],
#                 [
#                     "2005-01-28T00:00:00",
#                     0.9650228486316152
#                 ],
#                 [
#                     "2005-01-31T00:00:00",
#                     0.9348687343580598
#                 ],
#                 [
#                     "2005-02-01T00:00:00",
#                     0.9254253087858308
#                 ],
#                 [
#                     "2005-02-02T00:00:00",
#                     0.9770095143525884
#                 ],
#                 [
#                     "2005-02-03T00:00:00",
#                     0.9578288227128571
#                 ],
#                 [
#                     "2005-02-04T00:00:00",
#                     0.9747702471299889
#                 ],
#                 [
#                     "2005-02-16T00:00:00",
#                     0.9852167833584956
#                 ],
#                 [
#                     "2005-02-17T00:00:00",
#                     0.9902120717781403
#                 ],
#                 [
#                     "2005-02-18T00:00:00",
#                     0.9775465331887774
#                 ],
#                 [
#                     "2005-02-21T00:00:00",
#                     0.9948223278246685
#                 ],
#                 [
#                     "2005-02-22T00:00:00",
#                     1.0210349264892142
#                 ],
#                 [
#                     "2005-02-23T00:00:00",
#                     1.0327581490075284
#                 ],
#                 [
#                     "2005-02-24T00:00:00",
#                     1.038016880629832
#                 ],
#                 [
#                     "2005-02-25T00:00:00",
#                     1.0376825104110727
#                 ],
#                 [
#                     "2005-02-28T00:00:00",
#                     1.0343692055160953
#                 ],
#                 [
#                     "2005-03-01T00:00:00",
#                     1.0346833108731115
#                 ],
#                 [
#                     "2005-03-02T00:00:00",
#                     1.0194745321350045
#                 ],
#                 [
#                     "2005-03-03T00:00:00",
#                     1.0246826016029507
#                 ],
#                 [
#                     "2005-03-04T00:00:00",
#                     1.0164955974587864
#                 ],
#                 [
#                     "2005-03-07T00:00:00",
#                     1.020285126604724
#                 ],
#                 [
#                     "2005-03-08T00:00:00",
#                     1.0430932284964487
#                 ],
#                 [
#                     "2005-03-09T00:00:00",
#                     1.0462241496357392
#                 ],
#                 [
#                     "2005-03-10T00:00:00",
#                     1.0188564538518436
#                 ],
#                 [
#                     "2005-03-11T00:00:00",
#                     1.0227979694608533
#                 ],
#                 [
#                     "2005-03-14T00:00:00",
#                     1.021115985936186
#                 ],
#                 [
#                     "2005-03-15T00:00:00",
#                     1.0069913773013284
#                 ],
#                 [
#                     "2005-03-16T00:00:00",
#                     0.9969501383076814
#                 ],
#                 [
#                     "2005-03-17T00:00:00",
#                     0.9838286403291014
#                 ],
#                 [
#                     "2005-03-18T00:00:00",
#                     0.962084443678883
#                 ],
#                 [
#                     "2005-03-21T00:00:00",
#                     0.9621249734023689
#                 ],
#                 [
#                     "2005-03-22T00:00:00",
#                     0.9347775424802164
#                 ],
#                 [
#                     "2005-03-23T00:00:00",
#                     0.9354158856251205
#                 ],
#                 [
#                     "2005-03-24T00:00:00",
#                     0.9457104353905547
#                 ],
#                 [
#                     "2005-03-25T00:00:00",
#                     0.9437548762323569
#                 ],
#                 [
#                     "2005-0

# %%
zz500t2.dailyreport("2012-11-30")  # 看一下至暗时刻的投资表现
# Out:
#     基金名称     基金代码      当日净值    单位成本      持有份额      基金现值     基金总申购    历史最大占用  \
# 0  中证500  0000905  2.853925  3.6405  31643.62  90308.51  115200.0  115200.0
#
#      基金持有成本  基金分红与赎回       换手率    基金收益总额    投资收益率
# 0  115200.0      0.0  0.262968 -24891.49 -21.6072

# %%
zz500t2.dailyreport("2015-06-01")  # 收益率略有提高
# Out:
#     基金名称     基金代码       当日净值    单位成本      持有份额      基金现值     基金总申购    历史最大占用  \
# 0  中证500  0000905  10.627208  3.6838  63684.82  676791.8  234600.0  234600.0
#
#      基金持有成本  基金分红与赎回       换手率    基金收益总额     投资收益率
# 0  234600.0      0.0  0.113566  442191.8  188.4876

# %%
zz500t2.xirrrate("2015-06-01")  # 年化也小幅提高，不过即使对投资变额如此过优化，收益提升幅度还如此小，似乎意义不是很大
# Out:
# 0.49963825079451923

# %% [markdown]
# 最后，通过改变 pd.data_range() 中 freq 的标签，比如 W－WED，或M，可以调整定投在周几定投，或是按月定投，这里就不大篇幅回测其表现对比了，结论就是：收益都差不多
