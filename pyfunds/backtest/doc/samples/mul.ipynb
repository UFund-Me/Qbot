# %%
import xalpha as xa
import pandas as pd

xa.set_display("notebook")
# Out:
# holdings.py is found and loaded within xalpha dir

# %% [markdown]
# # 多基金投资系统的管理

# %% [markdown]
# ### 开放系统

# %%
path = "../../tests/demo.csv"
read = xa.record(path)
# 依旧先读取交易单的 csv 文件

# %%
sysopen = xa.mul(status=read.status)
# 基金投资组合既可以由一系列单个基金的交易类生成， 也可以直接依据给定的交易单一次性生成，这里采取后者

# %%
sysopen.combsummary().sort_values(by="基金现值", ascending=False)  # 先看一下今日投资组合概述
# Out:
#               基金名称    基金代码    当日净值    单位成本     持有份额     基金现值   基金总申购   历史最大占用  \
# 5               总计   total     NaN     NaN      NaN  2561.15  4197.0  3775.09
# 2      富国中证红利指数增强A  100032  0.9590  0.8869  1638.71  1571.52  1895.0  1633.66
# 0        广发医药卫生联接A  001180  0.9977  0.8310   630.39   628.94   600.0   523.86
# 4       工银中证传媒指数分级  164818  0.9679  1.2881   372.65   360.69   480.0   480.00
# 1  广发中债7-10年国开债指数A  003376  1.1586  0.0000     0.00     0.00   742.0   742.00
# 3    广发中证全指金融地产联接A  001469  0.9983  0.0000     0.00     0.00   480.0   480.00
#
#     基金持有成本  基金分红与赎回       换手率  基金收益总额    投资收益率
# 5  2515.35  1681.65  0.197882   45.80   1.2132
# 2  1453.40   441.60  0.199715  118.12   7.2304
# 0   523.86    76.14  0.180222  105.08  20.0588
# 4   480.00     0.00  0.139633 -119.31 -24.8562
# 1   -26.29   768.29  0.402455   26.29   3.5431
# 3    84.38   395.62  0.383988  -84.38 -17.5792

# %%
sysopen.xirrrate()  # 最重要的总是先问一下系统的整体收益年化如何
# Out:
# 0.004765231128134345

# %%
sysopen.v_positions("2018-06-01")  # 可视化指定日期的仓位分布
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="58cf9cc18d8f40758ef339e3b90b8bea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_58cf9cc18d8f40758ef339e3b90b8bea = echarts.init(
#                     document.getElementById('58cf9cc18d8f40758ef339e3b90b8bea'), 'white', {renderer: 'canvas'});
#                 var option_58cf9cc18d8f40758ef339e3b90b8bea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u603b\u503c\u5360\u6bd4",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA",
#                     "value": 972.24
#                 },
#                 {
#                     "name": "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A",
#                     "value": 560.01
#                 },
#                 {
#                     "name": "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A",
#                     "value": 420.77
#                 },
#                 {
#                     "name": "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A",
#                     "value": 257.53
#                 },
#                 {
#                     "name": "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7",
#                     "value": 165.05
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": false,
#                 "position": "center",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA",
#                 "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A",
#                 "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A",
#                 "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A",
#                 "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "left",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_58cf9cc18d8f40758ef339e3b90b8bea.setOption(option_58cf9cc18d8f40758ef339e3b90b8bea);
#         });
#     </script>

# %%
sysopen.v_positions_history()  # 基金组合就像一条河流。。。
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="99dea25ad313428bbeae1ac0d61de45c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_99dea25ad313428bbeae1ac0d61de45c = echarts.init(
#                     document.getElementById('99dea25ad313428bbeae1ac0d61de45c'), 'white', {renderer: 'canvas'});
#                 var option_99dea25ad313428bbeae1ac0d61de45c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "themeRiver",
#             "name": [
#                 "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A",
#                 "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A",
#                 "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA",
#                 "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A",
#                 "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#             ],
#             "data": [
#                 [
#                     "2016-09-28T00:00:00",
#                     698.95,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-09-28T00:00:00",
#                     270.0,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-09-28T00:00:00",
#                     199.76,
#                     "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-09-28T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A"
#                 ],
#                 [
#                     "2016-09-28T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-09-29T00:00:00",
#                     701.05,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-09-29T00:00:00",
#                     270.71,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-09-29T00:00:00",
#                     200.52,
#                     "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-09-29T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A"
#                 ],
#                 [
#                     "2016-09-29T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     703.15,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     271.41,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     201.61,
#                     "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A"
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-01T00:00:00",
#                     703.15,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-10-01T00:00:00",
#                     271.41,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-10-01T00:00:00",
#                     201.61,
#                     "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-01T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A"
#                 ],
#                 [
#                     "2016-10-01T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-02T00:00:00",
#                     703.15,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-10-02T00:00:00",
#                     271.41,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-10-02T00:00:00",
#                     201.61,
#                     "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-02T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A"
#                 ],
#                 [
#                     "2016-10-02T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-03T00:00:00",
#                     703.15,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-10-03T00:00:00",
#                     271.41,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-10-03T00:00:00",
#                     201.61,
#                     "\u5e7f\u53d1\u533b\u836f\u536b\u751f\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-03T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u503a7-10\u5e74\u56fd\u5f00\u503a\u6307\u6570A"
#                 ],
#                 [
#                     "2016-10-03T00:00:00",
#                     0,
#                     "\u5e7f\u53d1\u4e2d\u8bc1\u5168\u6307\u91d1\u878d\u5730\u4ea7\u8054\u63a5A"
#                 ],
#                 [
#                     "2016-10-04T00:00:00",
#                     703.15,
#                     "\u5bcc\u56fd\u4e2d\u8bc1\u7ea2\u5229\u6307\u6570\u589e\u5f3aA"
#                 ],
#                 [
#                     "2016-10-04T00:00:00",
#                     271.41,
#                     "\u5de5\u94f6\u4e2d\u8bc1\u4f20\u5a92\u6307\u6570\u5206\u7ea7"
#                 ],
#                 [
#                     "2016-10-04T00:00:00",
#                     201.61,

# %%
sysopen.v_tradevolume(freq="W")
# 整体交易情况一览, 以周为柱形图单位
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="deb795e74d7244469db4a145358c8635" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_deb795e74d7244469db4a145358c8635 = echarts.init(
#                     document.getElementById('deb795e74d7244469db4a145358c8635'), 'white', {renderer: 'canvas'});
#                 var option_deb795e74d7244469db4a145358c8635 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2016-09-29T00:00:00",
#                     -1170.0
#                 ],
#                 [
#                     "2017-10-19T00:00:00",
#                     -625.0
#                 ],
#                 [
#                     "2017-12-14T00:00:00",
#                     -442.1
#                 ],
#                 [
#                     "2018-01-18T00:00:00",
#                     -300.0
#                 ],
#                 [
#                     "2018-07-05T00:00:00",
#                     -1395.6
#                 ]
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5356\u51fa",
#             "data": [
#                 [
#                     "2017-01-19T00:00:00",
#                     157.5
#                 ],
#                 [
#                     "2018-07-26T00:00:00",
#                     1079.5
#                 ],
#                 [
#                     "2020-03-05T00:00:00",
#                     180.3
#                 ]
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e70\u5165",
#                 "\u5356\u51fa"
#             ],
#             "selected": {
#                 "\u4e70\u5165": true,
#                 "\u5356\u51fa": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "time",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2016-09-29T00:00:00",
#                 "2017-01-19T00:00:00",
#                 "2017-10-19T00:00:00",
#                 "2017-12-14T00:00:00",
#                 "2018-01-18T00:00:00",
#                 "2018-07-05T00:00:00",
#                 "2018-07-26T00:00:00",
#                 "2020-03-05T00:00:00"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "realtime": true,
#             "start": 99,
#             "end": 100,
#             "orient": "horizontal",
#             "zoomLock": false
#         }
#     ]
# };
#                 chart_deb795e74d7244469db4a145358c8635.setOption(option_deb795e74d7244469db4a145358c8635);
#         });
#     </script>

# %%
sysopen.totcftable  # 基金组合的合并现金流量表
# Out:
#         date     cash
# 0 2016-09-28 -1170.00
# 1 2017-01-17   157.54
# 2 2017-10-17  -625.00
# 3 2017-12-12  -442.06
# 4 2018-01-18  -300.00
# 5 2018-07-05 -1395.57
# 6 2018-07-26  1079.48
# 7 2020-02-28   180.26

# %%
ev = sysopen.evaluation(start="2018-01-01")  # 还可以生成关于投资基金的 evaluate 类，以便对投资的基金本身进行分析

# %%
ev.v_correlation(end="2018-08-01")  # 可以通过热力图来查看不同基金净值走势的相关性
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dc9e639ccb104fd9908d56d15d65e0dc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dc9e639ccb104fd9908d56d15d65e0dc = echarts.init(
#                     document.getElementById('dc9e639ccb104fd9908d56d15d65e0dc'), 'white', {renderer: 'canvas'});
#                 var option_dc9e639ccb104fd9908d56d15d65e0dc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u76f8\u5173\u6027",
#             "data": [
#                 [
#                     0,
#                     0,
#                     1.0
#                 ],
#                 [
#                     0,
#                     1,
#                     -0.17842946938725332
#                 ],
#                 [
#                     0,
#                     2,
#                     0.42008542418856165
#                 ],
#                 [
#                     0,
#                     3,
#                     0.38065566919242655
#                 ],
#                 [
#                     0,
#                     4,
#                     0.2702160975843602
#                 ],
#                 [
#                     1,
#                     0,
#                     -0.17842946938725332
#                 ],
#                 [
#                     1,
#                     1,
#                     1.0
#                 ],
#                 [
#                     1,
#                     2,
#                     -0.12922396128216726
#                 ],
#                 [
#                     1,
#                     3,
#                     -0.2507889154235432
#                 ],
#                 [
#                     1,
#                     4,
#                     -0.04201780647318538
#                 ],
#                 [
#                     2,
#                     0,
#                     0.42008542418856165
#                 ],
#                 [
#                     2,
#                     1,
#                     -0.12922396128216726
#                 ],
#                 [
#                     2,
#                     2,
#                     1.0
#                 ],
#                 [
#                     2,
#                     3,
#                     0.5709567544827989
#                 ],
#                 [
#                     2,
#                     4,
#                     0.1756000888447012
#                 ],
#                 [
#                     3,
#                     0,
#                     0.38065566919242655
#                 ],
#                 [
#                     3,
#                     1,
#                     -0.2507889154235432
#                 ],
#                 [
#                     3,
#                     2,
#                     0.5709567544827989
#                 ],
#                 [
#                     3,
#                     3,
#                     1.0
#                 ],
#                 [
#                     3,
#                     4,
#                     0.19104437341120778
#                 ],
#                 [
#                     4,
#                     0,
#                     0.2702160975843602
#                 ],
#                 [
#                     4,
#                     1,
#                     -0.04201780647318538
#                 ],
#                 [
#                     4,
#                     2,
#                     0.1756000888447012
#                 ],
#                 [
#                     4,
#                     3,
#                     0.19104437341120778
#                 ],
#                 [
#                     4,
#                     4,
#                     1.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f8\u5173\u6027"
#             ],
#             "selected": {
#                 "\u76f8\u5173\u6027": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "001180",
#                 "003376",
#                 "100032",
#                 "001469",
#                 "164818"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "001180",
#                 "003376",
#                 "100032",
#                 "001469",
#                 "164818"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": -1,
#         "max": 1,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "horizontal",
#         "top": "bottom",
#         "right": "middle",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_dc9e639ccb104fd9908d56d15d65e0dc.setOption(option_dc9e639ccb104fd9908d56d15d65e0dc);
#         });
#     </script>

# %% [markdown]
# ### 封闭系统
# 我们也可以研究一个封闭系统的组合投资，此时需要货币基金提供资金出入的功能，这样的系统净值更容易定义
# 可以应用之前研究指数和基金时使用过的量化方法。

# %%
sysopen.fundtradeobj
# Out:
# (广发医药卫生联接A 交易情况,
#  广发中债7-10年国开债指数A 交易情况,
#  富国中证红利指数增强A 交易情况,
#  广发中证全指金融地产联接A 交易情况,
#  工银中证传媒指数分级 交易情况)

# %%
# 这次我们使用基金交易类作为初始化参数
sysclose = xa.mulfix(*sysopen.fundtradeobj, totmoney=5000)
# totmoney 表示封闭系统初始的总钱数
# 若不设置 cashobj 选项，则默认为 cashobj = cashinfo(interest=0.0001, start='2012-01-01')

# %%
sysclose.unitvalue("2018-07-04")  # 封闭的基金投资组合整体就像一个单一基金交易类，有净值数据
# Out:
# 1.016426

# %%
sysclose.combsummary("2018-03-09")  # 投资组合的分项纵览
# Out:
#               基金名称    基金代码      当日净值    单位成本     持有份额     基金现值    基金总申购  \
# 6               总计   total       NaN     NaN      NaN  5295.35  6704.54
# 5             货币基金      mf  1.253436  1.1647  2249.86  2820.06  3987.54
# 2      富国中证红利指数增强A  100032  1.178000  0.9843   877.47  1033.66  1125.00
# 1  广发中债7-10年国开债指数A  003376  0.940300  0.9424   575.14   540.80   542.00
# 3    广发中证全指金融地产联接A  001469  1.059300  1.0758   446.20   472.66   480.00
# 0        广发医药卫生联接A  001180  0.876400  0.8134   275.20   241.19   300.00
# 4       工银中证传媒指数分级  164818  0.829600  1.1980   225.38   186.98   270.00
#
#     历史最大占用   基金持有成本  基金分红与赎回       换手率  基金收益总额    投资收益率
# 6  5000.00  5000.00  1704.54  0.346300  295.35   5.9070
# 5  3987.54  2620.48  1367.06  0.465023  199.58   5.0051
# 2   863.66   863.66   261.34  0.555878  170.00  19.6837
# 1   542.00   542.00     0.00  1.276224   -1.20  -0.2214
# 3   480.00   480.00     0.00  2.097701   -7.34  -1.5292
# 0   300.00   223.86    76.14  0.434191   17.33   5.7767
# 4   270.00   270.00     0.00  0.346300  -83.02 -30.7481

# %%
sysclose.bcmkset(xa.indexinfo("0000905"))  # 设置比较基准，开始对此封闭的基金投资系统进行量化评估

# %%
sysclose.v_netvalue()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4abd23922b9f4d338ef56811f3888513" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4abd23922b9f4d338ef56811f3888513 = echarts.init(
#                     document.getElementById('4abd23922b9f4d338ef56811f3888513'), 'white', {renderer: 'canvas'});
#                 var option_4abd23922b9f4d338ef56811f3888513 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u57fa\u91d1\u7ec4\u5408",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2016-09-28",
#                     1.0
#                 ],
#                 [
#                     "2016-09-29",
#                     1.000790203872599
#                 ],
#                 [
#                     "2016-09-30",
#                     1.0016464247775927
#                 ],
#                 [
#                     "2016-10-10",
#                     1.0061215793674767
#                 ],
#                 [
#                     "2016-10-11",
#                     1.0066937269815612
#                 ],
#                 [
#                     "2016-10-12",
#                     1.0065716954974384
#                 ],
#                 [
#                     "2016-10-13",
#                     1.0067057300783602
#                 ],
#                 [
#                     "2016-10-14",
#                     1.0061175783352103
#                 ],
#                 [
#                     "2016-10-17",
#                     1.0047832340743912
#                 ],
#                 [
#                     "2016-10-18",
#                     1.0075479473704216
#                 ],
#                 [
#                     "2016-10-19",
#                     1.0072278647891157
#                 ],
#                 [
#                     "2016-10-20",
#                     1.007273876660178
#                 ],
#                 [
#                     "2016-10-21",
#                     1.0073739024668362
#                 ],
#                 [
#                     "2016-10-24",
#                     1.0094724438905238
#                 ],
#                 [
#                     "2016-10-25",
#                     1.0100826013111384
#                 ],
#                 [
#                     "2016-10-26",
#                     1.0090643385993585
#                 ],
#                 [
#                     "2016-10-27",
#                     1.0086682364049924
#                 ],
#                 [
#                     "2016-10-28",
#                     1.007665977822278
#                 ],
#                 [
#                     "2016-10-31",
#                     1.007701987112675
#                 ],
#                 [
#                     "2016-11-01",
#                     1.0093924232451972
#                 ],
#                 [
#                     "2016-11-02",
#                     1.007515939112291
#                 ],
#                 [
#                     "2016-11-03",
#                     1.0087722632439167
#                 ],
#                 [
#                     "2016-11-04",
#                     1.0082981409203575
#                 ],
#                 [
#                     "2016-11-07",
#                     1.0081461016942372
#                 ],
#                 [
#                     "2016-11-08",
#                     1.0095944753746466
#                 ],
#                 [
#                     "2016-11-09",
#                     1.0080780841457098
#                 ],
#                 [
#                     "2016-11-10",
#                     1.0106827561510872
#                 ],
#                 [
#                     "2016-11-11",
#                     1.011300915636234
#                 ],
#                 [
#                     "2016-11-14",
#                     1.0120951205410997
#                 ],
#                 [
#                     "2016-11-15",
#                     1.0126812717681162
#                 ],
#                 [
#                     "2016-11-16",
#                     1.0129713466074246
#                 ],
#                 [
#                     "2016-11-17",
#                     1.013099379639947
#                 ],
#                 [
#                     "2016-11-18",
#                     1.0123951979610741
#                 ],
#                 [
#                     "2016-11-21",
#                     1.013751547899358
#                 ],
#                 [
#                     "2016-11-22",
#                     1.015660040290395
#                 ],
#                 [
#                     "2016-11-23",
#                     1.015732058871189
#                 ],
#                 [
#                     "2016-11-24",
#                     1.01618817654955
#                 ],
#                 [
#                     "2016-11-25",
#                     1.018050657069524
#                 ],
#                 [
#                     "2016-11-28",
#                     1.0189929001682434
#                 ],
#                 [
#                     "2016-11-29",
#                     1.0196410673953882
#                 ],
#                 [
#                     "2016-11-30",
#                     1.0186828201676033
#                 ],
#                 [
#                     "2016-12-01",
#                     1.0203612532033264
#                 ],
#                 [
#                     "2016-12-02",
#                     1.01766855848809
#                 ],
#                 [
#                     "2016-12-05",
#                     1.0152339303540314
#                 ],
#                 [
#                     "2016-12-06",
#                     1.0146897899658112
#                 ],
#                 [
#                     "2016-12-07",
#                     1.0160761476460927
#                 ],
#                 [
#                     "2016-12-08",
#                     1.0153639639026868
#                 ],
#                 [
#                     "2016-12-09",
#                     1.0160141316459645
#                 ],
#                 [
#                     "2016-12-12",
#                     1.0085462049208695
#                 ],
#                 [
#                     "2016-12-13",
#                     1.0083461533075533
#                 ],
#                 [
#                     "2016-12-14",
#                     1.0067057300783602
#                 ],
#                 [
#                     "2016-12-15",
#                     1.0054173976886036
#                 ],
#                 [
#                     "2016-12-16",
#                     1.007073825046862
#                 ],
#                 [
#                     "2016-12-19",
#                     1.0067097311106266
#                 ],
#                 [
#                     "2016-12-20",
#                     1.0058255029797687
#                 ],
#                 [
#                     "2016-12-21",
#                     1.0076119638866827
#                 ],
#                 [
#                     "2016-12-22",
#                     1.00756595201562
#                 ],
#                 [
#                     "2016-12-23",
#                     1.0054474054306013
#                 ],
#                 [
#                     "2016-12-26",
#                     1.0060015483994869

# %%
sysclose.alpha(), sysclose.beta(), sysclose.sharpe()
# Out:
# (0.013307324282019296, 0.3046674455277358, -0.17007378585189745)

# %%
sysclose.max_drawdown()  # 系统的最大回撤
# Out:
# (Timestamp('2018-01-24 00:00:00'),
#  Timestamp('2018-10-18 00:00:00'),
#  -0.1120821303964955)

# %%
sysclose.riskfree  # 进行量化计算中使用的无风险年化利率的参考值， 可在设置 benchmark 时调整该值
# Out:
# 0.0371724
