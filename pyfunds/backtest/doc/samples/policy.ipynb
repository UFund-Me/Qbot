# %%
import sys

sys.path.insert(0, "../../")
from pyecharts import online

online()
#  演示必要的准备代码，使用该库时不需重复此单元格命令

# %%
import xalpha as xa
import pandas as pd

# %% [markdown]
# # 策略制定类
# 生成简单的策略投资交易单，并储存在 self.status 中

# %% [markdown]
# ### 一次性买入并持有

# %%
jshs = xa.fundinfo("000311")
# 选择投资标的

# %%
bah = xa.policy.buyandhold(jshs, start="2017-01-01", totmoney=100000)
# 简单的一次性买入类，从 start 日买入后就一直持有，始终选择分红再投入

# %%
bah.status
# 第二三列表示此两日恰为分红日，选择了分红再投入
# Out:
#       000311       date
# 0  100000.00 2017-01-03
# 1       0.05 2017-08-04
# 2       0.05 2017-08-15

# %%
jshs.fenhongdate
# 验证该两日确实分红
# Out:
# [Timestamp('2017-08-04 00:00:00'), Timestamp('2017-08-15 00:00:00')]

# %%
bah.sellout("2018-06-01")  # 选定日期全部卖出

# %%
bah.status
# Out:
#        000311       date
# 0  100000.000 2017-01-03
# 1       0.050 2017-08-04
# 2       0.050 2017-08-15
# 3      -0.005 2018-06-01

# %%
jshstrade = xa.trade(jshs, bah.status)  # 尝试交易一下

# %%
jshstrade.xirrrate()
# Out:
# 0.15629726951248488

# %% [markdown]
# ### 定投类

# %%
# 依旧先制定标的
zzcm = xa.fundinfo("164818")
zzcm
# Out:
# 工银中证传媒指数分级

# %%
auto = xa.policy.scheduled(
    zzcm, 1000, pd.date_range("2015-07-01", "2018-07-01", freq="W-THU")
)
# 按照每周四定额定投1000，生成交易单

# %%
# 按上面的策略单子交易下
cm_t3 = xa.trade(zzcm, auto.status)

# %%
cm_t3.v_tradevolume()  # 交易情况可视化，那些明显的缝隙对应了小长假等，当次定投下单会被自动延后到下一个交易日
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="10a278e118c7446e8505f55328b85a1d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_10a278e118c7446e8505f55328b85a1d = echarts.init(document.getElementById('10a278e118c7446e8505f55328b85a1d'), 'light', {renderer: 'canvas'});
#
# var option_10a278e118c7446e8505f55328b85a1d = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4719573,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2015-07-02T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-07-09T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-07-16T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-07-23T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-07-30T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-08-06T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-08-13T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-08-20T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-08-27T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-09-07T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-09-10T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-09-17T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-09-24T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-10-08T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-10-15T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-10-22T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-10-29T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-11-05T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-11-12T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-11-19T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-11-26T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-12-03T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-12-10T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-12-17T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-12-24T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-12-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-01-07T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-01-14T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-01-21T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-01-28T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-02-04T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-02-15T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-02-18T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-02-25T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-03-03T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-03-10T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-03-17T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-03-24T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-03-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-04-07T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-04-14T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-04-21T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-04-28T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-05-05T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-05-12T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-05-19T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-05-26T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-06-02T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-06-13T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-06-16T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-06-23T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-06-30T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-07-07T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-07-14T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-07-21T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-07-28T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-08-04T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-08-11T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-08-18T00:00:00",
#                     -1000.0

# %%
cm_t3.dailyreport("2018-08-03")  ## 截止到2018.08.03， 定投已经浮亏了 40% 多
# Out:
#          基金名称    基金代码   当日净值    单位成本      持有份额      基金现值     基金总申购    历史最大占用  \
# 0  工银中证传媒指数分级  164818  0.935  1.6141  96030.82  89788.82  155000.0  155000.0
#
#      基金持有成本  基金分红与赎回       换手率    基金收益总额    投资收益率
# 0  155000.0      0.0  0.161791 -65211.18 -42.0717

# %% [markdown]
# 还可以根据指数位置设置定期不定额的定投策略生成，这里就不仔细展开，只给一个例子：

# %%
auto2 = xa.policy.scheduled_tune(
    zzcm,
    1000,
    pd.date_range("2015-07-01", "2018-07-01", freq="M"),
    [(0.9, 2), (1.2, 1)],
)  # 净值0.9以下加倍定投，1.2以上不再定投，中间正常定投

# %%
cm_t4 = xa.trade(zzcm, auto2.status)

# %%
cm_t4.v_tradevolume()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fe929efb43394d909e004c76358f6574" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fe929efb43394d909e004c76358f6574 = echarts.init(document.getElementById('fe929efb43394d909e004c76358f6574'), 'light', {renderer: 'canvas'});
#
# var option_fe929efb43394d909e004c76358f6574 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3924578,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2015-07-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-08-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2015-09-30T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2015-11-02T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-11-30T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2015-12-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2016-02-01T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-02-29T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-03-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-05-03T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-05-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-06-30T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-08-01T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-08-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-09-30T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-10-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2016-11-30T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2017-01-03T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2017-02-03T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2017-02-28T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2017-03-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2017-05-02T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2017-05-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2017-06-30T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2017-07-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2017-08-31T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2017-10-09T00:00:00",
#                     -1000.0
#                 ],
#                 [
#                     "2017-10-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2017-11-30T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2018-01-02T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2018-01-31T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2018-02-28T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2018-04-02T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2018-05-02T00:00:00",
#                     -2000.0
#                 ],
#                 [
#                     "2018-05-31T00:00:00",
#                     -2000.0
#                 ]
#             ],
#             "barCategoryGap": "35%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3924578
#         },
#         {
#             "type": "bar",
#             "name": "\u5356\u51fa",
#             "data": [],
#             "barCategoryGap": "35%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3924578
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e70\u5165",
#                 "\u5356\u51fa"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "time",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": []
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",

# %% [markdown]
# ### 网格类

# %%
gfc = xa.fundinfo("002903")
gfc
# 场外网格最好选择基金的C份额
# Out:
# 广发中证500ETF联接C

# %%
gr = xa.policy.grid(
    gfc, [3, 3, 3, 3, 3, 3], [6, 6, 6, 6, 6, 6], "2017-01-01", "2018-08-03"
)
# 制定一个 17年开始，18年8月结束的，以开始日期价格为基准，每下跌3%买入一仓，每仓买入上涨6%后卖出的网格策略，一共设置6档
## 注意网格对应的总金额可通过 totmoney= 参数设置，这里默认值是100000
## 卖出实际并不严格对应每次买入的份额，而是买入均分金额分仓，卖出均分持有份额分仓

# %%
gr.sellpts, gr.buypts  # 网格计划对应的卖点和买点净值
# Out:
# ([1.09791196,
#   1.0649746012000001,
#   1.0330253631639998,
#   1.0020346022690798,
#   0.97197356420100745,
#   0.9428143572749772],
#  [1.035766,
#   1.0046930199999999,
#   0.97455222939999986,
#   0.94531566251799981,
#   0.91695619264245976,
#   0.88944750686318597])

# %%
gfc.price.iloc[-4:-1]  # 事实上中证500已大幅跌破网格底线
# Out:
#      comment       date  netvalue  totvalue
# 524        0 2018-08-07    0.8629    0.8629
# 525        0 2018-08-08    0.8503    0.8503
# 526        0 2018-08-09    0.8713    0.8713

# %%
gfc_t = xa.trade(gfc, gr.status)  #  请开始你的交易

# %%
gfc_t.v_tradevolume(bar_category_gap="90%")  # 交易情况可视化
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="24b4007f810e43f79be242fea1e5803f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_24b4007f810e43f79be242fea1e5803f = echarts.init(document.getElementById('24b4007f810e43f79be242fea1e5803f'), 'light', {renderer: 'canvas'});
#
# var option_24b4007f810e43f79be242fea1e5803f = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6037742,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2017-01-16T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2017-05-05T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2017-05-10T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-02-01T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-02-06T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-02-09T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-03-23T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-05-30T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-06-15T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-06-19T00:00:00",
#                     -16666.67
#                 ],
#                 [
#                     "2018-06-21T00:00:00",
#                     -16666.67
#                 ]
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6037742
#         },
#         {
#             "type": "bar",
#             "name": "\u5356\u51fa",
#             "data": [
#                 [
#                     "2017-03-06T00:00:00",
#                     17906.01
#                 ],
#                 [
#                     "2017-07-31T00:00:00",
#                     17520.09
#                 ],
#                 [
#                     "2017-08-31T00:00:00",
#                     17971.37
#                 ],
#                 [
#                     "2018-03-01T00:00:00",
#                     17588.02
#                 ],
#                 [
#                     "2018-03-12T00:00:00",
#                     18154.829999999998
#                 ]
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6037742
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e70\u5165",
#                 "\u5356\u51fa"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "time",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 0,
#                 0,
#                 0,
#                 0,
#                 0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal"
#         }
#     ]
# };
# myChart_24b4007f810e43f79be242fea1e5803f.setOption(option_24b4007f810e43f79be242fea1e5803f);
#
#     });
# </script>

# %%
gfc_t.xirrrate("2018-04-01")  # 截止指定日期的年化收益率超过50%
# Out:
# 0.5110637968744924

# %%
gfc_t.xirrrate()  # 随着18年六七月份市场大跌，网格被跌穿，收益年化转负
# Out:
# -0.031232122333919685

# %%
gfc_t.v_totvalue()  # 网格投资持有基金的总值情况
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="dc594e55d668461eae6438b2790b1ddc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_dc594e55d668461eae6438b2790b1ddc = echarts.init(document.getElementById('dc594e55d668461eae6438b2790b1ddc'), 'light', {renderer: 'canvas'});
#
# var option_dc594e55d668461eae6438b2790b1ddc = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3403533,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "totvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2017-01-16T00:00:00",
#                     16666.67
#                 ],
#                 [
#                     "2017-01-17T00:00:00",
#                     16798.59
#                 ],
#                 [
#                     "2017-01-18T00:00:00",
#                     16766.01
#                 ],
#                 [
#                     "2017-01-19T00:00:00",
#                     16705.76
#                 ],
#                 [
#                     "2017-01-20T00:00:00",
#                     16901.19
#                 ],
#                 [
#                     "2017-01-23T00:00:00",
#                     17026.58
#                 ],
#                 [
#                     "2017-01-24T00:00:00",
#                     17011.93
#                 ],
#                 [
#                     "2017-01-25T00:00:00",
#                     17052.64
#                 ],
#                 [
#                     "2017-01-26T00:00:00",
#                     17158.5
#                 ],
#                 [
#                     "2017-02-03T00:00:00",
#                     17114.53
#                 ],
#                 [
#                     "2017-02-06T00:00:00",
#                     17239.93
#                 ],
#                 [
#                     "2017-02-07T00:00:00",
#                     17228.53
#                 ],
#                 [
#                     "2017-02-08T00:00:00",
#                     17324.61
#                 ],
#                 [
#                     "2017-02-09T00:00:00",
#                     17425.58
#                 ],
#                 [
#                     "2017-02-10T00:00:00",
#                     17440.24
#                 ],
#                 [
#                     "2017-02-13T00:00:00",
#                     17524.92
#                 ],
#                 [
#                     "2017-02-14T00:00:00",
#                     17537.95
#                 ],
#                 [
#                     "2017-02-15T00:00:00",
#                     17373.47
#                 ],
#                 [
#                     "2017-02-16T00:00:00",
#                     17495.61
#                 ],
#                 [
#                     "2017-02-17T00:00:00",
#                     17368.58
#                 ],
#                 [
#                     "2017-02-20T00:00:00",
#                     17564.01
#                 ],
#                 [
#                     "2017-02-21T00:00:00",
#                     17691.04
#                 ],
#                 [
#                     "2017-02-22T00:00:00",
#                     17792.01
#                 ],
#                 [
#                     "2017-02-23T00:00:00",
#                     17792.01
#                 ],
#                 [
#                     "2017-02-24T00:00:00",
#                     17800.15
#                 ],
#                 [
#                     "2017-02-27T00:00:00",
#                     17668.24
#                 ],
#                 [
#                     "2017-02-28T00:00:00",
#                     17736.64
#                 ],
#                 [
#                     "2017-03-01T00:00:00",
#                     17780.61
#                 ],
#                 [
#                     "2017-03-02T00:00:00",
#                     17700.81
#                 ],
#                 [
#                     "2017-03-03T00:00:00",
#                     17744.78
#                 ],
#                 [
#                     "2017-03-06T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-07T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-08T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-09T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-10T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-13T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-14T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-15T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-16T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-17T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-20T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-21T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-22T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-23T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-24T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-27T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-28T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-29T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-30T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-03-31T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-05T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-06T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-07T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-10T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-11T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-12T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-13T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2017-04-14T00:00:00",
#                     0.0
#                 ],
#                 [

# %%
# 考虑到网格的闲置资金可以在货基中吃收益，于是使用投资组合分析
gfc_cb = xa.mulfix(
    gfc_t, cashobj=xa.cashinfo(start="2016-10-01")
)  # 恰好 mulfix 类的默认 totmoney 也是 100000，我们无需在额外设置

# %%
gfc_cb.combsummary()
# Out:
#             基金名称    基金代码      当日净值    单位成本       持有份额       基金现值      基金总申购  \
# 0  广发中证500ETF联接C  002903  0.875800  0.8860  106310.30   93106.56  183333.37
# 1           货币基金      mf  1.070148  0.5975    9719.33   10401.12  172473.65
# 2             总计   total       NaN     NaN        NaN  103507.68  355807.02
#
#       历史最大占用     基金持有成本    基金分红与赎回       换手率   基金收益总额   投资收益率
# 0   94193.05   94193.05   89140.32  0.922938 -1086.49 -1.1535
# 1  103397.46    5806.95  166666.70  1.046493  4594.17  4.4432
# 2  100000.00  100000.00  255807.02  0.319056  3507.68  3.5077

# %%
gfc_cb.xirrrate()  # 系统总计收益年化勉强为正
# Out:
# 0.022243013394994196

# %% [markdown]
# ### 技术指标交叉类
# 利用模块内置的海量技术指标，可以制定各种基于不同技术指标的交叉进行交易的策略，同样的也可以指定基于净值和单个技术指标交叉的策略

# %%
hs300 = xa.indexinfo("0000300")  # 获取指数作为假想的无摩擦成本的投资标的

# %%
hs300.ma(window=14)  # 生成指数14天的均线

# %%
hs300.price.iloc[-1]  # 此时 info 类的 price 表将自动添加一列 MA14
# Out:
# date        2018-08-16 00:00:00
# netvalue                2.48904
# totvalue                3276.73
# comment                       0
# MA14                     2.5641
# Name: 4032, dtype: object

# %%
hs300.v_techindex(col=["MA14"], is_symbol_show=False)  # 均线和指数的纠缠
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="69e9afad805a4787815bcdadbabdd9c2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_69e9afad805a4787815bcdadbabdd9c2 = echarts.init(document.getElementById('69e9afad805a4787815bcdadbabdd9c2'), 'light', {renderer: 'canvas'});
#
# var option_69e9afad805a4787815bcdadbabdd9c2 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4413982,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "netvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": false,
#             "data": [
#                 [
#                     "2002-01-04T00:00:00",
#                     1.0
#                 ],
#                 [
#                     "2002-01-07T00:00:00",
#                     0.9890767664798018
#                 ],
#                 [
#                     "2002-01-08T00:00:00",
#                     0.981959193594944
#                 ],
#                 [
#                     "2002-01-09T00:00:00",
#                     0.9667213587955579
#                 ],
#                 [
#                     "2002-01-10T00:00:00",
#                     0.9732616258754538
#                 ],
#                 [
#                     "2002-01-11T00:00:00",
#                     0.9493718001306534
#                 ],
#                 [
#                     "2002-01-14T00:00:00",
#                     0.9154474879601355
#                 ],
#                 [
#                     "2002-01-15T00:00:00",
#                     0.9012275344484451
#                 ],
#                 [
#                     "2002-01-16T00:00:00",
#                     0.9129635537729973
#                 ],
#                 [
#                     "2002-01-17T00:00:00",
#                     0.8751880041930633
#                 ],
#                 [
#                     "2002-01-18T00:00:00",
#                     0.8731598377466843
#                 ],
#                 [
#                     "2002-01-21T00:00:00",
#                     0.8421144584719625
#                 ],
#                 [
#                     "2002-01-22T00:00:00",
#                     0.843162724275709
#                 ],
#                 [
#                     "2002-01-23T00:00:00",
#                     0.8987360041322943
#                 ],
#                 [
#                     "2002-01-24T00:00:00",
#                     0.9036203150874313
#                 ],
#                 [
#                     "2002-01-25T00:00:00",
#                     0.9035063731522417
#                 ],
#                 [
#                     "2002-01-28T00:00:00",
#                     0.8453200249153031
#                 ],
#                 [
#                     "2002-01-29T00:00:00",
#                     0.8662473603451681
#                 ],
#                 [
#                     "2002-01-30T00:00:00",
#                     0.8704100390441031
#                 ],
#                 [
#                     "2002-01-31T00:00:00",
#                     0.9280646582501557
#                 ],
#                 [
#                     "2002-02-01T00:00:00",
#                     0.9234917885845373
#                 ],
#                 [
#                     "2002-02-04T00:00:00",
#                     0.9396183704784042
#                 ],
#                 [
#                     "2002-02-05T00:00:00",
#                     0.9471157498138948
#                 ],
#                 [
#                     "2002-02-06T00:00:00",
#                     0.9242893821308661
#                 ],
#                 [
#                     "2002-02-07T00:00:00",
#                     0.9426948027285295
#                 ],
#                 [
#                     "2002-02-08T00:00:00",
#                     0.938190298224025
#                 ],
#                 [
#                     "2002-02-25T00:00:00",
#                     0.9530179420567277
#                 ],
#                 [
#                     "2002-02-26T00:00:00",
#                     0.9518861188338421
#                 ],
#                 [
#                     "2002-02-27T00:00:00",
#                     0.9540738039894869
#                 ],
#                 [
#                     "2002-02-28T00:00:00",
#                     0.94541421691506
#                 ],
#                 [
#                     "2002-03-01T00:00:00",
#                     0.9322197408200781
#                 ],
#                 [
#                     "2002-03-04T00:00:00",
#                     0.9463789252996672
#                 ],
#                 [
#                     "2002-03-05T00:00:00",
#                     0.9689698129833036
#                 ],
#                 [
#                     "2002-03-06T00:00:00",
#                     0.9787156465065403
#                 ],
#                 [
#                     "2002-03-07T00:00:00",
#                     1.0090621819120977
#                 ],
#                 [
#                     "2002-03-08T00:00:00",
#                     1.0268827005757866
#                 ],
#                 [
#                     "2002-03-11T00:00:00",
#                     1.0460173495586649
#                 ],
#                 [
#                     "2002-03-12T00:00:00",
#                     1.0348966166841378
#                 ],
#                 [
#                     "2002-03-13T00:00:00",
#                     1.020266472205764
#                 ],
#                 [
#                     "2002-03-14T00:00:00",
#                     1.0454780243987662
#                 ],
#                 [
#                     "2002-03-15T00:00:00",
#                     1.0168937909241451
#                 ],
#                 [
#                     "2002-03-18T00:00:00",
#                     1.0193321483372073
#                 ],
#                 [
#                     "2002-03-19T00:00:00",
#                     1.0394391018337057
#                 ],
#                 [
#                     "2002-03-20T00:00:00",
#                     1.0501040669674735
#                 ],
#                 [
#                     "2002-03-21T00:00:00",
#                     1.052663962444738
#                 ],
#                 [
#                     "2002-03-22T00:00:00",
#                     1.0405937134436292
#                 ],
#                 [
#                     "2002-03-25T00:00:00",
#                     1.042956109566565
#                 ],
#                 [
#                     "2002-03-26T00:00:00",
#                     1.025485012837458
#                 ],
#                 [
#                     "2002-03-27T00:00:00",
#                     1.0285918296036338
#                 ],
#                 [
#                     "2002-03-28T00:00:00",
#                     1.0273992373486471
#                 ],
#                 [
#                     "2002-03-29T00:00:00",
#                     0.997728757425216
#                 ],
#                 [
#                     "2002-04-01T00:00:00",
#                     1.0008507664494173
#                 ],
#                 [
#                     "2002-0

# %%
st = xa.policy.indicator_cross(hs300, start="2013-01-01", col=("netvalue", "MA14"))
# col 参量为一个两字符串的 tuple，每个代表标的价格表的一列名，当前者上穿后者时买入，反之卖出
# 具体到这里，就是最经典的一个趋势短线策略，价格涨过某条均线就买入，反之卖出

# %%
hs300_t = xa.trade(hs300, st.status)  # 模拟真实交易

# %%
hs300_t.dailyreport()  # 盈利一般
# Out:
#     基金名称     基金代码      当日净值  单位成本  持有份额  基金现值      基金总申购     历史最大占用    基金持有成本  \
# 0  沪深300  0000300  2.489045     0   0.0   0.0  9800000.0  112302.79 -41009.61
#
#       基金分红与赎回        换手率    基金收益总额   投资收益率
# 0  9841009.61  16.047277  41009.61  36.517

# %%
hs300_t.v_tradevolume()  # 交易详情，相当高频，换手率 16 代表每笔的持有时间约为 1/16 年，即不到一个月
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f2e30493ea9142d5bb601ceb0b002631" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f2e30493ea9142d5bb601ceb0b002631 = echarts.init(document.getElementById('f2e30493ea9142d5bb601ceb0b002631'), 'light', {renderer: 'canvas'});
#
# var option_f2e30493ea9142d5bb601ceb0b002631 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3624381,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e70\u5165",
#             "data": [
#                 [
#                     "2013-03-06T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-03-20T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-04-19T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-04-24T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-05-03T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-05-15T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-07-10T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-07-23T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-08-01T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-08-26T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-09-02T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-10-09T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-10-11T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-10-21T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-11-15T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2013-12-31T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-01-22T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-02-07T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-03-21T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-05-12T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-05-23T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-06-05T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-06-10T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-06-30T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-07-14T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-07-22T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-08-15T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-08-22T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-09-01T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-09-19T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-09-24T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-10-20T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-10-29T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-11-21T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2014-12-25T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-01-21T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-02-12T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-03-09T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-05-11T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-05-19T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-06-01T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-07-13T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-07-17T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-08-10T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-09-09T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-09-16T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-09-22T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-10-08T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-11-04T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-11-25T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-12-02T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-12-14T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2015-12-29T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2016-02-16T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2016-03-02T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2016-03-14T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2016-03-30T00:00:00",
#                     -100000.0
#                 ],
#                 [
#                     "2016-04-11T00:00:00",
#                     -100000.0

# %%
hs300_t.v_tradecost(is_symbol_show=False)  # 持仓成本降低缓慢
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="527688bdc06f4d8b96f1c73c6a0fbeee" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_527688bdc06f4d8b96f1c73c6a0fbeee = echarts.init(document.getElementById('527688bdc06f4d8b96f1c73c6a0fbeee'), 'light', {renderer: 'canvas'});
#
# var option_527688bdc06f4d8b96f1c73c6a0fbeee = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1665353,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "fundvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2002-01-04T00:00:00",
#                     1.0
#                 ],
#                 [
#                     "2002-01-07T00:00:00",
#                     0.9890767664798018
#                 ],
#                 [
#                     "2002-01-08T00:00:00",
#                     0.981959193594944
#                 ],
#                 [
#                     "2002-01-09T00:00:00",
#                     0.9667213587955579
#                 ],
#                 [
#                     "2002-01-10T00:00:00",
#                     0.9732616258754538
#                 ],
#                 [
#                     "2002-01-11T00:00:00",
#                     0.9493718001306534
#                 ],
#                 [
#                     "2002-01-14T00:00:00",
#                     0.9154474879601355
#                 ],
#                 [
#                     "2002-01-15T00:00:00",
#                     0.9012275344484451
#                 ],
#                 [
#                     "2002-01-16T00:00:00",
#                     0.9129635537729973
#                 ],
#                 [
#                     "2002-01-17T00:00:00",
#                     0.8751880041930633
#                 ],
#                 [
#                     "2002-01-18T00:00:00",
#                     0.8731598377466843
#                 ],
#                 [
#                     "2002-01-21T00:00:00",
#                     0.8421144584719625
#                 ],
#                 [
#                     "2002-01-22T00:00:00",
#                     0.843162724275709
#                 ],
#                 [
#                     "2002-01-23T00:00:00",
#                     0.8987360041322943
#                 ],
#                 [
#                     "2002-01-24T00:00:00",
#                     0.9036203150874313
#                 ],
#                 [
#                     "2002-01-25T00:00:00",
#                     0.9035063731522417
#                 ],
#                 [
#                     "2002-01-28T00:00:00",
#                     0.8453200249153031
#                 ],
#                 [
#                     "2002-01-29T00:00:00",
#                     0.8662473603451681
#                 ],
#                 [
#                     "2002-01-30T00:00:00",
#                     0.8704100390441031
#                 ],
#                 [
#                     "2002-01-31T00:00:00",
#                     0.9280646582501557
#                 ],
#                 [
#                     "2002-02-01T00:00:00",
#                     0.9234917885845373
#                 ],
#                 [
#                     "2002-02-04T00:00:00",
#                     0.9396183704784042
#                 ],
#                 [
#                     "2002-02-05T00:00:00",
#                     0.9471157498138948
#                 ],
#                 [
#                     "2002-02-06T00:00:00",
#                     0.9242893821308661
#                 ],
#                 [
#                     "2002-02-07T00:00:00",
#                     0.9426948027285295
#                 ],
#                 [
#                     "2002-02-08T00:00:00",
#                     0.938190298224025
#                 ],
#                 [
#                     "2002-02-25T00:00:00",
#                     0.9530179420567277
#                 ],
#                 [
#                     "2002-02-26T00:00:00",
#                     0.9518861188338421
#                 ],
#                 [
#                     "2002-02-27T00:00:00",
#                     0.9540738039894869
#                 ],
#                 [
#                     "2002-02-28T00:00:00",
#                     0.94541421691506
#                 ],
#                 [
#                     "2002-03-01T00:00:00",
#                     0.9322197408200781
#                 ],
#                 [
#                     "2002-03-04T00:00:00",
#                     0.9463789252996672
#                 ],
#                 [
#                     "2002-03-05T00:00:00",
#                     0.9689698129833036
#                 ],
#                 [
#                     "2002-03-06T00:00:00",
#                     0.9787156465065403
#                 ],
#                 [
#                     "2002-03-07T00:00:00",
#                     1.0090621819120977
#                 ],
#                 [
#                     "2002-03-08T00:00:00",
#                     1.0268827005757866
#                 ],
#                 [
#                     "2002-03-11T00:00:00",
#                     1.0460173495586649
#                 ],
#                 [
#                     "2002-03-12T00:00:00",
#                     1.0348966166841378
#                 ],
#                 [
#                     "2002-03-13T00:00:00",
#                     1.020266472205764
#                 ],
#                 [
#                     "2002-03-14T00:00:00",
#                     1.0454780243987662
#                 ],
#                 [
#                     "2002-03-15T00:00:00",
#                     1.0168937909241451
#                 ],
#                 [
#                     "2002-03-18T00:00:00",
#                     1.0193321483372073
#                 ],
#                 [
#                     "2002-03-19T00:00:00",
#                     1.0394391018337057
#                 ],
#                 [
#                     "2002-03-20T00:00:00",
#                     1.0501040669674735
#                 ],
#                 [
#                     "2002-03-21T00:00:00",
#                     1.052663962444738
#                 ],
#                 [
#                     "2002-03-22T00:00:00",
#                     1.0405937134436292
#                 ],
#                 [
#                     "2002-03-25T00:00:00",
#                     1.042956109566565
#                 ],
#                 [
#                     "2002-03-26T00:00:00",
#                     1.025485012837458
#                 ],
#                 [
#                     "2002-03-27T00:00:00",
#                     1.0285918296036338
#                 ],
#                 [
#                     "2002-03-28T00:00:00",
#                     1.0273992373486471
#                 ],
#                 [
#                     "2002-03-29T00:00:00",
#                     0.997728757425216
#                 ],
#                 [
#                     "2002-04-01T00:00:00",
#                     1.0008507664494173
#                 ],
#                 [
#                     "2002-0

# %%
sti = xa.policy.indicator_cross(hs300, start="2013-01-01", col=("MA14", "netvalue"))
# 我们看下交易策略彻底反转会发生什么

# %%
hs300_ti = xa.trade(hs300, sti.status)

# %%
hs300_ti.dailyreport()  # 跌穿均线买入涨出均线卖出，果然赔钱，噗
# Out:
#     基金名称     基金代码      当日净值   单位成本      持有份额      基金现值      基金总申购     历史最大占用  \
# 0  沪深300  0000300  2.489045  2.597  38187.17  95049.57  9900000.0  113045.02
#
#      基金持有成本     基金分红与赎回        换手率   基金收益总额   投资收益率
# 0  99170.71  9800829.29  15.870778 -4121.14 -3.6456

# %% [markdown]
# ### 基于技术指标点位的策略
# 除了指标间的交叉，我们还可以给定几个不同的点位来买卖，其中也可以不给卖的点位，这相当于可以模拟熊市的网格底仓

# %%
hs300.roc(window=20)  # 先生成一个追涨杀跌的动量类变动率指标

# %%
st = xa.policy.indicator_points(
    hs300,
    start="2016-01-01",
    col="ROC20",
    buy=[(-0.08, 1), (-0.11, 2)],
    sell=[(0.06, 1), (0.1, 1)],
    buylow=True,
)
# 这个策略的含义时，跌破点位买，涨破点位跌， 这是 buylow 这个布尔量的意义，默认就是 true
# 点位看的是 ROC20 一栏，这是 col 参数决定的，交易从 16年开始，默认昨天结束
# 买点分别是 ROC 的值为 －8% 和 －11%， 分别买1/3，和2/3
# 卖点分别是 ROC 为 6% 和 8%， 各卖一半

# %%
hs300_t = xa.trade(hs300, st.status)

# %%
hs300_t.dailyreport()  # 追跌杀涨好像效果一般
# Out:
#     基金名称     基金代码      当日净值    单位成本     持有份额      基金现值     基金总申购    历史最大占用  \
# 0  沪深300  0000300  2.489045  2.7577  37516.8  93380.99  200000.0  103461.1
#
#      基金持有成本  基金分红与赎回       换手率    基金收益总额   投资收益率
# 0  103461.1  96538.9  0.549453 -10080.11 -9.7429

# %%
hs300_t.v_totvalue()  # 持有总金额的变化
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0e5a6f4578e44b038f31c45bda9f049f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0e5a6f4578e44b038f31c45bda9f049f = echarts.init(document.getElementById('0e5a6f4578e44b038f31c45bda9f049f'), 'light', {renderer: 'canvas'});
#
# var option_0e5a6f4578e44b038f31c45bda9f049f = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3017337,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "totvalue",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2016-01-07T00:00:00",
#                     33333.32
#                 ],
#                 [
#                     "2016-01-08T00:00:00",
#                     34013.05
#                 ],
#                 [
#                     "2016-01-11T00:00:00",
#                     98968.59
#                 ],
#                 [
#                     "2016-01-12T00:00:00",
#                     99689.67
#                 ],
#                 [
#                     "2016-01-13T00:00:00",
#                     97834.86
#                 ],
#                 [
#                     "2016-01-14T00:00:00",
#                     99871.37
#                 ],
#                 [
#                     "2016-01-15T00:00:00",
#                     96683.21
#                 ],
#                 [
#                     "2016-01-18T00:00:00",
#                     97055.19
#                 ],
#                 [
#                     "2016-01-19T00:00:00",
#                     99919.55
#                 ],
#                 [
#                     "2016-01-20T00:00:00",
#                     98408.35
#                 ],
#                 [
#                     "2016-01-21T00:00:00",
#                     95524.26
#                 ],
#                 [
#                     "2016-01-22T00:00:00",
#                     96519.92
#                 ],
#                 [
#                     "2016-01-25T00:00:00",
#                     96998.06
#                 ],
#                 [
#                     "2016-01-26T00:00:00",
#                     91158.2
#                 ],
#                 [
#                     "2016-01-27T00:00:00",
#                     90843.34
#                 ],
#                 [
#                     "2016-01-28T00:00:00",
#                     88468.81
#                 ],
#                 [
#                     "2016-01-29T00:00:00",
#                     91331.24
#                 ],
#                 [
#                     "2016-02-01T00:00:00",
#                     89934.88
#                 ],
#                 [
#                     "2016-02-02T00:00:00",
#                     91803.8
#                 ],
#                 [
#                     "2016-02-03T00:00:00",
#                     91410.24
#                 ],
#                 [
#                     "2016-02-04T00:00:00",
#                     92530.03
#                 ],
#                 [
#                     "2016-02-05T00:00:00",
#                     91879.93
#                 ],
#                 [
#                     "2016-02-15T00:00:00",
#                     91350.34
#                 ],
#                 [
#                     "2016-02-16T00:00:00",
#                     94150.61
#                 ],
#                 [
#                     "2016-02-17T00:00:00",
#                     94965.45
#                 ],
#                 [
#                     "2016-02-18T00:00:00",
#                     94667.18
#                 ],
#                 [
#                     "2016-02-19T00:00:00",
#                     94601.66
#                 ],
#                 [
#                     "2016-02-22T00:00:00",
#                     96687.47
#                 ],
#                 [
#                     "2016-02-23T00:00:00",
#                     95772.82
#                 ],
#                 [
#                     "2016-02-24T00:00:00",
#                     96398.48
#                 ],
#                 [
#                     "2016-02-25T00:00:00",
#                     90483.67
#                 ],
#                 [
#                     "2016-02-26T00:00:00",
#                     91391.39
#                 ],
#                 [
#                     "2016-02-29T00:00:00",
#                     89203.85
#                 ],
#                 [
#                     "2016-03-01T00:00:00",
#                     90853.93
#                 ],
#                 [
#                     "2016-03-02T00:00:00",
#                     94593.84
#                 ],
#                 [
#                     "2016-03-03T00:00:00",
#                     47406.79
#                 ],
#                 [
#                     "2016-03-04T00:00:00",
#                     47956.56
#                 ],
#                 [
#                     "2016-03-07T00:00:00",
#                     48126.29
#                 ],
#                 [
#                     "2016-03-08T00:00:00",
#                     48170.2
#                 ],
#                 [
#                     "2016-03-09T00:00:00",
#                     47615.82
#                 ],
#                 [
#                     "2016-03-10T00:00:00",
#                     46704.99
#                 ],
#                 [
#                     "2016-03-11T00:00:00",
#                     46784.65
#                 ],
#                 [
#                     "2016-03-14T00:00:00",
#                     47519.46
#                 ],
#                 [
#                     "2016-03-15T00:00:00",
#                     47660.35
#                 ],
#                 [
#                     "2016-03-16T00:00:00",
#                     47896.78
#                 ],
#                 [
#                     "2016-03-17T00:00:00",
#                     48426.44
#                 ],
#                 [
#                     "2016-03-18T00:00:00",
#                     49166.73
#                 ],
#                 [
#                     "2016-03-21T00:00:00",
#                     50367.61
#                 ],
#                 [
#                     "2016-03-22T00:00:00",
#                     50001.07
#                 ],
#                 [
#                     "2016-03-23T00:00:00",
#                     50160.76
#                 ],
#                 [
#                     "2016-03-24T00:00:00",
#                     49319.99
#                 ],
#                 [
#                     "2016-03-25T00:00:00",
#                     49567.47
#                 ],
#                 [
#                     "2016-03-28T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2016-03-29T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2016-03-30T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2016-03-31T00:00:00",
#                     0.0
#                 ],
#                 [
#                     "2016-04-01T00:00:00",
#                     0.0
#                 ],
#                 [
